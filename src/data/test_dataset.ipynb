# %% [markdown]
# # Test Train Dataset

# %%
from dataset import train_dataset,test_dataset
real_img, anime_img = train_dataset[0]
print(real_img.shape)
print(anime_img.shape)
import matplotlib.pyplot as plt
plt.imshow(real_img.permute(1,2,0) * 0.5 + 0.5)
plt.show()
plt.imshow(anime_img.permute(1,2,0) * 0.5 + 0.5)
plt.show()
# Out:
# torch.Size([3, 256, 256])
# torch.Size([3, 256, 256])

# %% [markdown]
# # Test Test Dataset

# %%
real_img, anime_img = test_dataset[0]
print(real_img.shape)
print(anime_img.shape)
plt.imshow(real_img.permute(1,2,0) * 0.5 + 0.5)
plt.show()
plt.imshow(anime_img.permute(1,2,0) * 0.5 + 0.5)
plt.show()
# Out:
# torch.Size([3, 350, 286])
# torch.Size([3, 286, 286])
